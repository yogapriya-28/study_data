# %% [markdown]
# <a href="https://colab.research.google.com/github/yogapriya-28/study_data/blob/main/study_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df=pd.read_csv("/content/study_data.csv")
df
# Out:
#      repetition_time  study_time knowledge_level
# 0               0.00        0.00             Low
# 1               0.24        0.90            High
# 2               0.25        0.33             Low
# 3               0.65        0.30            High
# 4               0.98        0.24             Low
# ..               ...         ...             ...
# 253             0.92        0.58            High
# 254             0.19        0.60            High
# 255             0.29        0.77            High
# 256             0.61        0.26            High
# 257             0.87        0.74            High
#
# [258 rows x 3 columns]

# %%
from sklearn.preprocessing import LabelEncoder #scikit learn
muthu=LabelEncoder()
for j in df.select_dtypes(include="object").columns:
  df[j]=muthu.fit_transform(df[j])

# %%
df
# Out:
#      repetition_time  study_time  knowledge_level
# 0               0.00        0.00                1
# 1               0.24        0.90                0
# 2               0.25        0.33                1
# 3               0.65        0.30                0
# 4               0.98        0.24                1
# ..               ...         ...              ...
# 253             0.92        0.58                0
# 254             0.19        0.60                0
# 255             0.29        0.77                0
# 256             0.61        0.26                0
# 257             0.87        0.74                0
#
# [258 rows x 3 columns]
